# %%
# Import Dependencies
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np

# %%
# Store filepath in a variable
dataset_csv = "./dataset_immigrantstat.csv"
immigrant_stat_df = pd.read_csv(dataset_csv)
immigrant_stat_df
# Out:
#                               Regions Geographic area type abbreviation  \
# 0                             Barrie                                CMA
# 1           Belleville - Quinte West                                CMA
# 2                          Brantford                                CMA
# 3                         Brockville                                 CA
# 4                  Centre Wellington                                 CA
# 5                       Chatham-Kent                                 CA
# 6                            Cobourg                                 CA
# 7                        Collingwood                                 CA
# 8                           Cornwall                                 CA
# 9                        Elliot Lake                                 CA
# 10                              Essa                                 CA
# 11                   Greater Sudbury                                CMA
# ...

# %%
# Create a DataFrame with columns to total: Before 2001, 2001 to 2005, 2006 to 2010, 
# 2011 to 2015, 2016 to 2021, Non-immigrants, Immigrants, Non-PR residents 

immigrant_total_df = immigrant_stat_df[['Regions', 'Total_Immigrants',
                                        'Before_2001', '2001_to_2005', '2006_to_2010', 
                                         '2011_to_2015', '2016_to_2021']]
immigrant_total_df.head()
# Out:
#                      Regions  Total_Immigrants  Before_2001  2001_to_2005  \
# 0                    Barrie              35340        20395          3465
# 1  Belleville - Quinte West               9065         6040           730
# 2                 Brantford              20235        12485          1735
# 3                Brockville               2855         2075           155
# 4         Centre Wellington               3450         2615           215
#
#    2006_to_2010  2011_to_2015  2016_to_2021
# 0          3545          3780          4160
# 1           740           685           870
# 2          1855          1885          2265
# 3           200           165           260
# 4           225           175           220

# %%
# Region name
Region_name = immigrant_stat_df.set_index(["Regions"]).groupby(["Regions"])
Region_name

# %%
# Calculate the total number of Regions in Ontario
Region_count = len(immigrant_stat_df["Total "].unique())
Region_count
# Out:
# 47

# %%
Per_Region_count = immigrant_stat_df.set_index("Regions")["Total_Immigrants"]
Per_Region_count
# Out:
# Regions
# Barrie                                 35340
# Belleville - Quinte West                9065
# Brantford                              20235
# Brockville                              2855
# Centre Wellington                       3450
# Chatham-Kent                            9245
# Cobourg                                 2550
# Collingwood                             3205
# Cornwall                                4525
# Elliot Lake                             1175
# Essa                                    2685
# Greater Sudbury                         9985
# Guelph                                 37100
# Hamilton                              197845
# Hawkesbury                               625
# Hawkesbury (Ontario part)                580
# Hawkesbury (Quebec part)                  50
# Ingersoll                               1030
# Kawartha Lakes                          6100
# Kenora                                   640
# Kingston                               20290
# ...

# %%
# Calculate the total number of immigrants in Ontario till 2021
immigrant_count = immigrant_stat_df["Total_Immigrants"].sum()
immigrant_count
# Out:
# 4463680

# %%
average_before_2001 = immigrant_stat_df.groupby(["Regions"]).mean()["Before_2001"]
average_before_2001.head()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4340\1412515660.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   average_before_2001 = immigrant_stat_df.groupby(["Regions"]).mean()["Before_2001"]
# Regions
# Barrie                       20395.0
# Belleville - Quinte West      6040.0
# Brantford                    12485.0
# Brockville                    2075.0
# Centre Wellington             2615.0
# Name: Before_2001, dtype: float64

# %%
average_2001_to_2005 = immigrant_stat_df.groupby(["Regions"]).mean()["2001_to_2005"]
average_2001_to_2005.head()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4340\1738160188.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   average_2001_to_2005 = immigrant_stat_df.groupby(["Regions"]).mean()["2001_to_2005"]
# Regions
# Barrie                       3465.0
# Belleville - Quinte West      730.0
# Brantford                    1735.0
# Brockville                    155.0
# Centre Wellington             215.0
# Name: 2001_to_2005, dtype: float64

# %%
average_2006_to_2010 = immigrant_stat_df.groupby(["Regions"]).mean()["2006_to_2010"]
average_2006_to_2010.head()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4340\1415694324.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   average_2006_to_2010 = immigrant_stat_df.groupby(["Regions"]).mean()["2006_to_2010"]
# Regions
# Barrie                       3545.0
# Belleville - Quinte West      740.0
# Brantford                    1855.0
# Brockville                    200.0
# Centre Wellington             225.0
# Name: 2006_to_2010, dtype: float64

# %%
average_2011_to_2015 = immigrant_stat_df.groupby(["Regions"]).mean()["2011_to_2015"]
average_2011_to_2015.head()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4340\2523827086.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   average_2011_to_2015 = immigrant_stat_df.groupby(["Regions"]).mean()["2011_to_2015"]
# Regions
# Barrie                       3780.0
# Belleville - Quinte West      685.0
# Brantford                    1885.0
# Brockville                    165.0
# Centre Wellington             175.0
# Name: 2011_to_2015, dtype: float64

# %%
average_2016_to_2021 = immigrant_stat_df.groupby(["Regions"]).mean()["2016_to_2021"]
average_2016_to_2021.head()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4340\989522850.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   average_2016_to_2021 = immigrant_stat_df.groupby(["Regions"]).mean()["2016_to_2021"]
# Regions
# Barrie                       4160.0
# Belleville - Quinte West      870.0
# Brantford                    2265.0
# Brockville                    260.0
# Centre Wellington             220.0
# Name: 2016_to_2021, dtype: float64

# %%
# Calculate the number of immigrants per region before 2001 with 100,000 or higher immigrants
Immigrant_Before_2001 = immigrant_stat_df[immigrant_stat_df["Before_2001"] >= 100000]
Region_Immigrant_Before_2001 = Immigrant_Before_2001.groupby(["Regions"]).count()["Before_2001"]

# %%
# Calculate the number of immigrants per region from 2001 to 2005 with 100,000 or higher immigrants
Immigrant_2001_to_2005 = immigrant_stat_df[immigrant_stat_df["2001_to_2005"] >= 100000]
Region_Immigrant_2001_to_2005 = Immigrant_2001_to_2005.groupby(["Regions"]).count()["2001_to_2005"]

# %%
# Calculate the number of immigrants per region from 2006 to 2010 with 100,000 or higher immigrants
Immigrant_2006_to_2010 = immigrant_stat_df[immigrant_stat_df["2006_to_2010"] >= 100000]
Region_Immigrant_2006_to_2010 = Immigrant_2006_to_2010.groupby(["Regions"]).count()["2006_to_2010"]

# %%
# Calculate the number of immigrants per region from 2011 to 2015 with 100,000 or higher immigrants
Immigrant_2011_to_2015 = immigrant_stat_df[immigrant_stat_df["2011_to_2015"] >= 100000]
Region_Immigrant_2011_to_2015 = Immigrant_2011_to_2015.groupby(["Regions"]).count()["2011_to_2015"]

# %%
# Calculate the number of immigrants per region from 2011 to 2015 with 100,000 or higher immigrants
Immigrant_2016_to_2021 = immigrant_stat_df[immigrant_stat_df["2016_to_2021"] >= 100000]
Region_Immigrant_2016_to_2021 = Immigrant_2016_to_2021.groupby(["Regions"]).count()["2016_to_2021"]

# %%
# Use the provided code to calculate the overall immigration rates
per_region_immigration_Before_2001 = Region_Immigrant_Before_2001 / Per_Region_count * 100
per_region_immigration_2001_to_2005 = Region_Immigrant_2001_to_2005 / Per_Region_count * 100
per_region_immigration_2006_to_2010 = Region_Immigrant_2006_to_2010 / Per_Region_count * 100
per_region_immigration_2011_to_2015 = Region_Immigrant_2011_to_2015 / Per_Region_count * 100
per_region_immigration_2016_to_2021 = Region_Immigrant_2016_to_2021 / Per_Region_count * 100
overall_Immigration_rate = school_students_passing_math_and_reading/ Per_Region_count * 100

# %%
# Create a DataFrame called `per_year_summary` with columns for the calculations above.
per_year_summary = pd.DataFrame({"Regions" : Regions,
                                  "Total Students" : per_school_counts,
                                  "Total School Budget" : per_school_budget,
                                  "Per Student Budget" : per_school_capita,
                                  "Average Math Score" : per_school_math,
                                  "Average Reading Score": per_school_reading,
                                  "% Passing Math" : per_school_passing_math,
                                  "% Passing Reading": per_school_passing_reading,
                                  "% Overall Passing": overall_passing_rate})

# Formatting
per_year_summary["Total School Budget"] = per_year_summary["Total School Budget"].map("${:,.2f}".format)
per_year_summary["Per Student Budget"] = per_year_summary["Per Student Budget"].map("${:,.2f}".format)
per_year_summary.index.name = None

# Display the DataFrame
per_year_summary
